# %% [markdown]
# ### To fatch the information from Facebook Graph API

# %%
import requests

# %% [markdown]
# ### Genrate access token by creating Account on FB graph API

# %%
token = "EAARsfrk2NN4BAB4ZCOb3Lyuu53l5nHDgE3sJ5IIEWyFAP6RkBdp8qWZC0ZCZBgtNHBsh8fZAOxVPQ5gshWuoA4cB9rFky4ml7RrdIAYn3oWwBajQVM8Qo3Y7DtxZBaYmyZBhhrdvLtb1MwcfnqaDFZB4JId9XDhwAZBW9BaD69YGWpPBZA0Yz2746zM0ZBTbHHqXS0SErllCd5HYG8gchtcXjaHxmMbaC9VfyUMtsKNY0tLEwZDZD"

# %%
profile_details = "https://graph.Facebook.com/v2.9/me?access_token="+token

# %%
profile_pic = "https://graph.Facebook.com/2334035490213205/picture?type=large"

# %%
r = requests.get(profile_details)

# %%
r1 = requests.get(profile_pic)

# %%
print(r1)
# Out:
# <Response [200]>

# %%
print(r)
# Out:
# <Response [200]>

# %%
#profile Details
print(r.content)
# Out:
# b'{"name":"Singhania Deepak","id":"2802231820060234"}'

# %%
# profile picture 
print(r1.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14ElnEuVXpp69I9_oge44g\x1c\x02(\x00bFBMD0a000a880100002b04000055070000640800001b090000df0a0000b70e00006c0f000097100000761100000c180000\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc2\x00\x11\x08\x00\xc8\x00\xc8\x03\x01"B\x15\x14\x8dD\x13\x08L\xed\xad\x86
# ...

# %%
with open("pic.jpg",'wb') as f:
    f.write(r1.content)
